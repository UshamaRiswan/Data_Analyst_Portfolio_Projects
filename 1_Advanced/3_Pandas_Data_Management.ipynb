# %%
# Importing Libraries 
import pandas as pd
from datasets import load_dataset
import matplotlib as plt

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# 0               False  Texas, United States 2023-06-16 13:44:15
# 1               False                Mexico 2023-01-14 13:18:07
# 2               False               Germany 2023-10-10 13:14:55
# 3               False  Texas, United States 2023-07-04 13:01:41
# 4               False                 Sudan 2023-08-07 14:29:36
#
#    job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# 0                  False                 False  United States        None
# 1                  False                 False         Mexico        None
# 2                  False                 False        Germany        None
# 3                   True                 False  United States        None
# 4                  False                 False          Sudan        None
#
#    salary_year_avg  salary_hour_avg                  company_name  \
# 0              NaN              NaN          Boehringer Ingelheim
# 1              NaN              NaN    Hewlett Packard Enterprise
# 2              NaN              NaN      ALPHA Augmented Services
# 3              NaN              NaN  Southwest Research Institute
# 4              NaN              NaN               Kristina Daniel
#
#                                           job_skills  \
# 0                                               None
# 1  ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2  ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3  ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4  ['bash', 'python', 'oracle', 'aws', 'ansible',...
#
#                                      job_type_skills
# 0                                               None
# 1  {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2  {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3  {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4  {'cloud': ['oracle', 'aws'], 'other': ['ansibl...

# %%
df.sample(10, random_state=41)
# Out:
#           job_title_short                                          job_title  \
# 476634       Data Analyst                   Data Analytics Developer | AD824
# 364748     Data Scientist  PhD position on data science with tensor decom...
# 744884  Software Engineer                           Senior Software Engineer
# 599937       Data Analyst               Functional Data Analyst - Investment
# 265529   Business Analyst                                         BI Analyst
# 219602   Business Analyst  BI Business Analytics and Process Engineer - R...
# 770385       Data Analyst                                       Data Analyst
# 286495      Data Engineer                                Data Engineer on W2
# 452968      Data Engineer                                   Data Engineer II
# 390803     Data Scientist  Data Scientist-Business Intelligence Engineer ...
#
#                            job_location                               job_via  \
# 476634  Cali, Valle del Cauca, Colombia                        via Kit Empleo
# 364748                          Belgium                          via Mendeley
# 744884                      Philippines                       via Trabajo.org
# 599937                Brussels, Belgium                            via Indeed
# 265529                  Dublin, Ireland                     via BeBee Ireland
# 219602            San Juan, Puerto Rico  via Whatjobs? Jobs In The PuertoRico
# 770385                 Philadelphia, PA                            via Indeed
# 286495                       Dallas, TX                          via LinkedIn
# 452968                       Remote, OR        via SmartRecruiters Job Search
# 390803                     Richmond, VA                         via WANE Jobs
#
#        job_schedule_type  job_work_from_home            search_location  \
# 476634         Full-time               False                   Colombia
# 364748         Full-time               False                    Belgium
# 744884         Full-time               False                Philippines
# 599937        Contractor               False                    Belgium
# 265529         Full-time               False                    Ireland
# 219602         Full-time               False                Puerto Rico
# 770385         Full-time               False    New York, United States
# 286495        Contractor               False    New York, United States
# 452968         Full-time               False  California, United States
# 390803         Full-time               False                    Georgia
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 476634 2023-01-03 23:48:28                  False                 False
# 364748 2023-06-22 23:55:25                  False                 False
# 744884 2023-02-19 20:14:08                   True                 False
# 599937 2023-11-28 09:35:41                  False                 False
# 265529 2023-01-05 07:50:12                   True                 False
# 219602 2023-10-25 23:38:31                  False                 False
# 770385 2023-01-26 01:00:09                  False                  True
# 286495 2023-12-04 17:05:35                  False                 False
# 452968 2023-03-29 14:28:27                   True                 False
# 390803 2023-05-20 18:08:30                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 476634       Colombia        None              NaN              NaN
# 364748        Belgium        None              NaN              NaN
# 744884    Philippines        None              NaN              NaN
# 599937        Belgium        None              NaN              NaN
# 265529        Ireland        None              NaN              NaN
# 219602    Puerto Rico        None              NaN              NaN
# 770385  United States        year          56212.5              NaN
# 286495  United States        None              NaN              NaN
# 452968  United States        None              NaN              NaN
# 390803  United States        None              NaN              NaN
#
#                         company_name  \
# 476634                     Bairesdev
# 364748                     KU Leuven
# 744884                         Appen
# 599937       Oliver James Associates
# 265529  search talent people limited
# 219602             Ryder System, Inc
# 770385                 CORA Services
# 286495      AALPHA PRIME TECH GLOBAL
# 452968               insightsoftware
# 390803                Wolters Kluwer
#
#                                                job_skills  \
# 476634  ['sql', 'python', 'sql server', 'tableau', 'ss...
# 364748                               ['matlab', 'python']
# 744884  ['c', 'python', 'java', 'shell', 'groovy', 'po...
# 599937                             ['python', 'r', 'sql']
# 265529      ['sql', 'python', 'r', 'tableau', 'power bi']
# 219602  ['sql', 'microstrategy', 'power bi', 'tableau'...
# 770385    ['sql', 'tableau', 'power bi', 'excel', 'word']
# 286495  ['python', 'shell', 'java', 'sql', 'bigquery',...
# 452968  ['python', 'sql', 'sql server', 'aws', 'azure'...
# 390803  ['r', 'python', 'sql', 'aws', 'redshift', 'tab...
#
#                                           job_type_skills
# 476634  {'analyst_tools': ['tableau', 'ssis'], 'databa...
# 364748              {'programming': ['matlab', 'python']}
# 744884  {'cloud': ['aws', 'redshift', 'gcp'], 'databas...
# 599937            {'programming': ['python', 'r', 'sql']}
# 265529  {'analyst_tools': ['tableau', 'power bi'], 'pr...
# 219602  {'analyst_tools': ['microstrategy', 'power bi'...
# 770385  {'analyst_tools': ['tableau', 'power bi', 'exc...
# 286495  {'cloud': ['bigquery', 'azure', 'databricks', ...
# 452968  {'analyst_tools': ['ssis'], 'cloud': ['aws', '...
# 390803  {'analyst_tools': ['tableau', 'power bi', 'qli...

# %%
dataset = load_dataset('lukebarousse/data_jobs')
df_original = dataset['train'].to_pandas()

# %%
df_altered = df_original

# %%
df_altered.loc[:5,'salary_year_avg']
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# Name: salary_year_avg, dtype: float64

# %%
median_salary = df_altered['salary_year_avg'].median()

median_salary
# Out:
# 115000.0

# %%
df_altered['salary_year_avg'] = df_altered['salary_year_avg'].fillna(median_salary)

df_altered.loc[:5,'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
id(df_original)
# Out:
# 1842110197312

# %%
id(df_altered)
# Out:
# 1842110197312

# %%
dataset = load_dataset('lukebarousse/data_jobs')
df_original = dataset['train'].to_pandas()

# %%
df_altered = df_original.copy()

# %%
print('id of the original:          ', id(df_original))
print('id of df_altered:            ', id(df_altered))
print('Are the two same?            ', id(df_original) == id(df_altered) )
# Out:
# id of the original:           1840472332560
# id of df_altered:             1841063353600
# Are the two same?             False
